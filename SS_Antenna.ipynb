# %% [markdown]
# <a href="https://colab.research.google.com/github/tamojeetroychowdhury/Spectral-Analysis/blob/main/SS_Antenna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from astropy.io import fits
from astropy.convolution import convolve, Box1DKernel
import matplotlib.pyplot as plt
import numpy as np

# %%
for i in range(1,13):
  f = fits.open(f'gdrive/My Drive/SS/NGC4038/3 ({i}).fits')
  d = f[1].data
  l = d['WAVE'][0][np.where(d['WAVE'][0] > 550)]
  f = d['FLUX_REDUCED'][0][np.where(d['WAVE'][0] > 550)]

  #spec = Spectrum1D(spectral_axis=l*u.AA, flux=f*u.Jy)

  #g1_fit = fit_generic_continuum(spec)
  #y_continuum_fitted = g1_fit(l * u.AA)

  #spec -= y_continuum_fitted

  plt.figure(figsize=(20,7))
  plt.vlines(np.array([410.2,434,447.2,486.1,501.8,396.8])*10*1.0055, np.max(f),np.min(f))
  plt.plot(l,f)
  plt.show()

# %%
for i in range(1):  
  f = fits.open(f'gdrive/My Drive/SS/NGC4038/Antenna_SN.fits')
  d = f[1].data
  l = d['WAVE'][0][np.where(d['WAVE'][0] > 550)]
  f = d['FLUX_REDUCED'][0][np.where(d['WAVE'][0] > 550)]

  #spec = Spectrum1D(spectral_axis=l*u.AA, flux=f*u.Jy)

  #g1_fit = fit_generic_continuum(spec)
  #y_continuum_fitted = g1_fit(l * u.AA)

  #spec -= y_continuum_fitted

  plt.figure(figsize=(20,7))
  plt.vlines(np.array([410.2,434,447.2,486.1,501.8,396.8])*10*1.0055, np.max(f),np.min(f))
  plt.plot(l,f)
  plt.show()
